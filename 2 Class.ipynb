# %% [markdown]
# # Basic Class
# ## Example Function
# ```python
# import math
#
# def area_of_diameter(diameter):
#     """ docstring
#     Calculate the area of a circle given its diameter.
#
#     Parameters:
#         diameter (float): The diameter of the circle.
#
#     Returns:
#         float: The area of the circle.
#     """
#     radius = diameter / 2
#     return math.pi * math.pow(raduis,2) #radius ** 2
#
# def area_of_rectangle(length, width):
#     """
#     Calculate the area of a rectangle.
#
#     Parameters:
#         length (float): The length of the rectangle.
#         width (float): The width of the rectangle.
#
#     Returns:
#         float: The area of the rectangle.
#     """
#     return length * width
#
# def total_area_of_steel(n, area_of_diameter):
#     """
#     Calculate the total area of steel.
#
#     Parameters:
#         n (int): The number of steel bars.
#         area_of_diameter (float): The area of a single steel bar.
#
#     Returns:
#         float: The total area of steel.
#     """
#     return n * area_of_diameter
#
# def steel_ratio(total_area_of_steel, rectangular_area):
#     """
#     Calculate the steel ratio.
#
#     Parameters:
#         total_area_of_steel (float): The total area of steel.
#         rectangular_area (float): The area of the rectangle.
#
#     Returns:
#         float: The steel ratio.
#     """
#     return total_area_of_steel / rectangular_area
#
#
# diameter = 16  # Example diameter in mm
# length = 300   # Example length in mm
# width = 500    # Example width in mm
# n = 4          # Example number of steel bars
#
# area_d = area_of_diameter(diameter)
# area_r = area_of_rectangle(length, width)
# total_steel = total_area_of_steel(n, area_d)
# ratio = steel_ratio(total_steel, area_r)
#
# print(f"Area of diameter: {area_d:.2f} mm^2")
# print(f"Area of rectangle: {area_r:.2f} mm^2")
# print(f"Total area of steel: {total_steel:.2f} mm^2")
# print(f"Steel ratio: {ratio:.4f}")
# ```

# %%
import math 

def area_of_diameter(diameter):
    """ docstring
    Calculate the area of a circle given its diameter.
    
    Parameters:
        diameter (float): The diameter of the circle.

    Returns:
        float: The area of the circle.
    """
    radius = diameter / 2
    return math.pi * math.pow(radius,2) #radius ** 2

def area_of_rectangle(length, width):
    """
    Calculate the area of a rectangle.
    
    Parameters:
        length (float): The length of the rectangle.
        width (float): The width of the rectangle.

    Returns:
        float: The area of the rectangle.
    """
    return length * width

def total_area_of_steel(n, area_of_diameter):
    """
    Calculate the total area of steel.
    
    Parameters:
        n (int): The number of steel bars.
        area_of_diameter (float): The area of a single steel bar.

    Returns:
        float: The total area of steel.
    """
    return n * area_of_diameter

def steel_ratio(total_area_of_steel, rectangular_area):
    """
    Calculate the steel ratio.
    
    Parameters:
        total_area_of_steel (float): The total area of steel.
        rectangular_area (float): The area of the rectangle.

    Returns:
        float: The steel ratio.
    """
    return total_area_of_steel / rectangular_area


diameter = 16  # Example diameter in mm
length = 300   # Example length in mm
width = 500    # Example width in mm
n = 4          # Example number of steel bars

area_d = area_of_diameter(diameter)
area_r = area_of_rectangle(length, width)
total_steel = total_area_of_steel(n, area_d)
ratio = steel_ratio(total_steel, area_r)

print(f"Area of diameter: {area_d:.2f} mm^2")
print(f"Area of rectangle: {area_r:.2f} mm^2")
print(f"Total area of steel: {total_steel:.2f} mm^2")
print(f"Steel ratio: {ratio:.4f}")
# Out:
# Area of diameter: 201.06 mm^2
# Area of rectangle: 150000.00 mm^2
# Total area of steel: 804.25 mm^2
# Steel ratio: 0.0054

# %% [markdown]
# # Example of Class
# ```python
# import math
#
# class SteelCalculation:
#     """
#     A class to perform various steel-related calculations such as area of diameter,
#     area of rectangle, total area of steel, and steel ratio.
#     """
#
#     def __init__(self, diameter, length, width, n):
#         """
#         Initialize the SteelCalculation class with predefined values.
#
#         Parameters:
#             diameter (float): Diameter of the steel bar.
#             length (float): Length of the rectangle.
#             width (float): Width of the rectangle.
#             n (int): Number of steel bars.
#         """
#         self.diameter = diameter
#         self.length = length
#         self.width = width
#         self.n = n
#
#     def area_of_diameter(self):
#         """
#         Calculate the area of a circle given its diameter.
#
#         Returns:
#             float: The area of the circle.
#         """
#         radius = self.diameter / 2
#         return math.pi * radius ** 2
#
#     def area_of_rectangle(self):
#         """
#         Calculate the area of a rectangle.
#
#         Returns:
#             float: The area of the rectangle.
#         """
#         return self.length * self.width
#
#     def total_area_of_steel(self):
#         """
#         Calculate the total area of steel.
#
#         Returns:
#             float: The total area of steel.
#         """
#         return self.n * self.area_of_diameter()
#
#     def steel_ratio(self):
#         """
#         Calculate the steel ratio.
#
#         Returns:
#             float: The steel ratio.
#         """
#         return self.total_area_of_steel() / self.area_of_rectangle()
#
#
# # Predefined values
# diameter = 16  # Example diameter in mm
# length = 300   # Example length in mm
# width = 500    # Example width in mm
# n = 4          # Example number of steel bars
#
# steel_calc = SteelCalculation(diameter, length, width, n)
#
# area_d = steel_calc.area_of_diameter()
# area_r = steel_calc.area_of_rectangle()
# total_steel = steel_calc.total_area_of_steel()
# ratio = steel_calc.steel_ratio()
#
# print(f"Area of diameter: {area_d:.2f} mm^2")
# print(f"Area of rectangle: {area_r:.2f} mm^2")
# print(f"Total area of steel: {total_steel:.2f} mm^2")
# print(f"Steel ratio: {ratio:.4f}")
# ```

# %%
import math

class SteelCalculation:
    """
    A class to perform various steel-related calculations such as area of diameter,
    area of rectangle, total area of steel, and steel ratio.
    """

    def __init__(self, diameter, length, width, n):
        """
        Initialize the SteelCalculation class with predefined values.
        
        Parameters:
            diameter (float): Diameter of the steel bar.
            length (float): Length of the rectangle.
            width (float): Width of the rectangle.
            n (int): Number of steel bars.
        """
        self.diameter = diameter
        self.length = length
        self.width = width
        self.n = n

    def area_of_diameter(self):
        """
        Calculate the area of a circle given its diameter.

        Returns:
            float: The area of the circle.
        """
        radius = self.diameter / 2
        return math.pi * radius ** 2

    def area_of_rectangle(self):
        """
        Calculate the area of a rectangle.

        Returns:
            float: The area of the rectangle.
        """
        return self.length * self.width

    def total_area_of_steel(self):
        """
        Calculate the total area of steel.

        Returns:
            float: The total area of steel.
        """
        return self.n * self.area_of_diameter()

    def steel_ratio(self):
        """
        Calculate the steel ratio.

        Returns:
            float: The steel ratio.
        """
        return self.total_area_of_steel() / self.area_of_rectangle()


# Predefined values
diameter = 16  # Example diameter in mm
length = 300   # Example length in mm
width = 500    # Example width in mm
n = 4          # Example number of steel bars

steel_calc = SteelCalculation(diameter, length, width, n)

#area_d = steel_calc.area_of_diameter()
#area_r = steel_calc.area_of_rectangle()
#total_steel = steel_calc.total_area_of_steel()
ratio = steel_calc.steel_ratio()

#print(f"Area of diameter: {area_d:.2f} mm^2")
#print(f"Area of rectangle: {area_r:.2f} mm^2")
#print(f"Total area of steel: {total_steel:.2f} mm^2")
print(f"Steel ratio: {ratio:.4f}")
# Out:
# Steel ratio: 0.0054
